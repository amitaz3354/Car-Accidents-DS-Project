# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv('teuonot.csv')

# %%
data.head()
# Out:
#    THUM_GEOGRAFI  SUG_DEREH  HODESH_TEUNA  SHAA  SUG_YOM  YOM_LAYLA  \
# 0              1          2             1    75        4          5
# 1              1          4             7    67        4          1
# 2              1          2             6    82        4          5
# 3              1          1             7    54        4          1
# 4              1          2             3    47        4          1
#
#    YOM_BASHAVUA  HUMRAT_TEUNA  SUG_TEUNA  HAD_MASLUL  RAV_MASLUL  \
# 0             5             2          2           0           3
# 1             5             3         11           0           4
# 2             2             3          1           9           0
# 3             4             1          4           0           3
# 4             1             3          2           1           0
#
#    MEHIRUT_MUTERET  TKINUT  ROHAV  SIMUN_TIMRUR  TEURA  MEZEG_AVIR  PNE_KVISH
# 0                1       1      2             3      3           1          1
# ...

# %%
#q1  = what is the distribution of the accidents in 2017 0
#1  - Deadly
#2  - Hard
#3 - Easy
sns.countplot(data['HUMRAT_TEUNA'])

# %%
sns.countplot(data['SUG_DEREH'],hue=data['HUMRAT_TEUNA'])

# %%
sns.countplot(data['THUM_GEOGRAFI'],hue=data['HUMRAT_TEUNA'])

# %%
sns.countplot(data['YOM_LAYLA'],hue=data['HUMRAT_TEUNA'])

# %%
sns.countplot(data['SUG_YOM'],hue=data['HUMRAT_TEUNA'])

# %%
sns.countplot(data['YOM_BASHAVUA'],hue=data['HUMRAT_TEUNA'])

# %%
sns.countplot(data['SUG_TEUNA'],hue=data['HUMRAT_TEUNA'])

# %%
sns.countplot(data['MEHIRUT_MUTERET'],hue=data['HUMRAT_TEUNA'])

# %%
sns.countplot(data['TKINUT'],hue=data['HUMRAT_TEUNA'])

# %%
sns.countplot(data['SIMUN_TIMRUR'],hue=data['HUMRAT_TEUNA'])

# %%
sns.countplot(data['MEZEG_AVIR'],hue=data['HUMRAT_TEUNA'])

# %%
sns.countplot(data['PNE_KVISH'],hue=data['HUMRAT_TEUNA'])

# %%
sns.countplot(data['TEURA'],hue=data['HUMRAT_TEUNA'])

# %%
sns.countplot(data['PNE_KVISH'],hue=data['HUMRAT_TEUNA'])

# %%
sns.countplot(data['HODESH_TEUNA'],hue=data['HUMRAT_TEUNA'])

# %%
sns.heatmap(data.corr())
